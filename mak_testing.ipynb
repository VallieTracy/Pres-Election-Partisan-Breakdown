# %%
import pandas as pd

# %%
countiesDF = pd.read_csv("Resources/countypres_2000-2016.csv")
countiesDF
# Out:
#        year    state state_po       county    FIPS     office  \
# 0      2000  Alabama       AL      Autauga  1001.0  President
# 1      2000  Alabama       AL      Autauga  1001.0  President
# 2      2000  Alabama       AL      Autauga  1001.0  President
# 3      2000  Alabama       AL      Autauga  1001.0  President
# 4      2000  Alabama       AL      Baldwin  1003.0  President
# ...     ...      ...      ...          ...     ...        ...
# 50519  2016   Alaska       AK  District 40  2040.0  President
# 50520  2016   Alaska       AK  District 40  2040.0  President
# 50521  2016   Alaska      NaN  District 99  2099.0  President
# 50522  2016   Alaska      NaN  District 99  2099.0  President
# 50523  2016   Alaska      NaN  District 99  2099.0  President
#
#              candidate       party  candidatevotes  totalvotes   version
# 0              Al Gore    democrat          4942.0       17208  20191203
# 1       George W. Bush  republican         11993.0       17208  20191203
# 2          Ralph Nader       green           160.0       17208  20191203
# 3                Other         NaN           113.0       17208  20191203
# 4              Al Gore    democrat         13997.0       56480  20191203
# ...                ...         ...             ...         ...       ...
# 50519     Donald Trump  republican          1377.0        4610  20191203
# 50520            Other         NaN           895.0        4610  20191203
# 50521  Hillary Clinton    democrat           274.0        5056  20191203
# 50522     Donald Trump  republican            40.0        5056  20191203
# 50523            Other         NaN            28.0        5056  20191203
#
# [50524 rows x 11 columns]

# %%
df2016 = countiesDF[(countiesDF["year"]==2016)]
df2016 = df2016.groupby(['FIPS', 'county'], as_index = False).sum()
df2016

# %%
# Set file path
csvpath = "Resources/2016-precinct-president.csv"

# Read csv and preview dataframe
prec_df = pd.read_csv(csvpath, encoding="ISO-8859-1")
pd.set_option('display.max_columns', None)
prec_df
# Out:
#          year stage  special    state state_postal  state_fips  state_icpsr  \
# 0        2016   gen    False  Alabama           AL           1           41
# 1        2016   gen    False  Alabama           AL           1           41
# 2        2016   gen    False  Alabama           AL           1           41
# 3        2016   gen    False  Alabama           AL           1           41
# 4        2016   gen    False  Alabama           AL           1           41
# ...       ...   ...      ...      ...          ...         ...          ...
# 1989229  2016   gen    False  Wyoming           WY          56           68
# 1989230  2016   gen    False  Wyoming           WY          56           68
# 1989231  2016   gen    False  Wyoming           WY          56           68
# 1989232  2016   gen    False  Wyoming           WY          56           68
# 1989233  2016   gen    False  Wyoming           WY          56           68
#
#             county_name  county_fips  county_ansi  county_lat  county_long  \
# 0        Autauga County       1001.0     161526.0   32.532237    -86.64644
# 1        Autauga County       1001.0     161526.0   32.532237    -86.64644
# 2        Autauga County       1001.0     161526.0   32.532237    -86.64644
# 3        Autauga County       1001.0     161526.0   32.532237    -86.64644
# 4        Autauga County       1001.0     161526.0   32.532237    -86.64644
# ...                 ...          ...          ...         ...          ...
# 1989229   Weston County      56045.0    1605086.0   43.846210   -104.57000
# 1989230   Weston County      56045.0    1605086.0   43.846210   -104.57000
# 1989231   Weston County      56045.0    1605086.0   43.846210   -104.57000
# 1989232   Weston County      56045.0    1605086.0   43.846210   -104.57000
# 1989233   Weston County      56045.0    1605086.0   43.846210   -104.57000
#
#         jurisdiction                                 precinct  \
# 0            Autauga                   10 JONES COMMUNITY CTR
# 1            Autauga                   10 JONES COMMUNITY CTR
# 2            Autauga                   10 JONES COMMUNITY CTR
# 3            Autauga                   10 JONES COMMUNITY CTR
# 4            Autauga                   10 JONES COMMUNITY CTR
# ...              ...                                      ...
# 1989229       Weston  Newcastle - State Forestry Building 5-3
# 1989230       Weston  Newcastle - State Forestry Building 5-3
# 1989231       Weston  Newcastle - State Forestry Building 5-3
# 1989232       Weston  Newcastle - State Forestry Building 5-3
# 1989233       Weston  Newcastle - State Forestry Building 5-3
#
#                   candidate candidate_normalized        office   district  \
# 0           Hillary Clinton              clinton  US President  statewide
# 1              Gary Johnson              johnson  US President  statewide
# 2                Jill Stein                stein  US President  statewide
# 3              Donald Trump                trump  US President  statewide
# 4                [Write-in]                   in  US President  statewide
# ...                     ...                  ...           ...        ...
# 1989229     Hillary Clinton              clinton  US President  statewide
# 1989230  Rocky De La Fuente               fuente  US President  statewide
# 1989231        Gary Johnson              johnson  US President  statewide
# 1989232          Jill Stein                stein  US President  statewide
# 1989233        Donald Trump                trump  US President  statewide
#
#          writein        party          mode  votes  candidate_opensecrets  \
# 0          False   democratic  election day    135                    NaN
# 1          False  independent  election day      0                    NaN
# 2          False  independent  election day      1                    NaN
# 3          False   republican  election day    218                    NaN
# 4           True          NaN  election day      4                    NaN
# ...          ...          ...           ...    ...                    ...
# 1989229    False   democratic         total     63                    NaN
# 1989230    False  independent         total      0                    NaN
# 1989231    False  libertarian         total     28                    NaN
# 1989232    False  independent         total      2                    NaN
# 1989233    False   republican         total    412                    NaN
#
#          candidate_wikidata  candidate_party  candidate_last  candidate_first  \
# 0                       NaN              NaN             NaN              NaN
# 1                       NaN              NaN             NaN              NaN
# 2                       NaN              NaN             NaN              NaN
# 3                       NaN              NaN             NaN              NaN
# 4                       NaN              NaN             NaN              NaN
# ...                     ...              ...             ...              ...
# 1989229                 NaN              NaN             NaN              NaN
# 1989230                 NaN              NaN             NaN              NaN
# 1989231                 NaN              NaN             NaN              NaN
# 1989232                 NaN              NaN             NaN              NaN
# 1989233                 NaN              NaN             NaN              NaN
#
#          candidate_middle  candidate_full  candidate_suffix  \
# 0                     NaN             NaN               NaN
# 1                     NaN             NaN               NaN
# 2                     NaN             NaN               NaN
# 3                     NaN             NaN               NaN
# 4                     NaN             NaN               NaN
# ...                   ...             ...               ...
# 1989229               NaN             NaN               NaN
# 1989230               NaN             NaN               NaN
# 1989231               NaN             NaN               NaN
# 1989232               NaN             NaN               NaN
# 1989233               NaN             NaN               NaN
#
#          candidate_nickname candidate_fec  \
# 0                       NaN     P00003392
# 1                       NaN     P60012234
# 2                       NaN     P20003984
# 3                       NaN     P80001571
# 4                       NaN           NaN
# ...                     ...           ...
# 1989229                 NaN     P00003392
# 1989230                 NaN     P60016342
# 1989231                 NaN     P60012234
# 1989232                 NaN     P20003984
# 1989233                 NaN     P80001571
#
#                                       candidate_fec_name  candidate_google  \
# 0        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE               NaN
# 1                           JOHNSON, JOHN FITZGERALD MR.               NaN
# 2                                            STEIN, JILL               NaN
# 3                    TRUMP, DONALD J. / MICHAEL R. PENCE               NaN
# 4                                                    NaN               NaN
# ...                                                  ...               ...
# 1989229  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE               NaN
# 1989230                        DE LA FUENTE, ROQUE ROCKY               NaN
# 1989231                     JOHNSON, JOHN FITZGERALD MR.               NaN
# 1989232                                      STEIN, JILL               NaN
# 1989233              TRUMP, DONALD J. / MICHAEL R. PENCE               NaN
#
#          candidate_govtrack  candidate_icpsr  candidate_maplight
# 0                       NaN              NaN                 NaN
# 1                       NaN              NaN                 NaN
# 2                       NaN              NaN                 NaN
# 3                       NaN              NaN                 NaN
# 4                       NaN              NaN                 NaN
# ...                     ...              ...                 ...
# 1989229                 NaN              NaN                 NaN
# 1989230                 NaN              NaN                 NaN
# 1989231                 NaN              NaN                 NaN
# 1989232                 NaN              NaN                 NaN
# 1989233                 NaN              NaN                 NaN
#
# [1989234 rows x 37 columns]

# %%
mn_prec_df = prec_df.loc[prec_df['state'] == 'Minnesota']
mn_prec_df.head(20)

# %%
mn_prec_df = mn_prec_df.groupby(mn_prec_df["precinct"], as_index=False).sum()
mn_prec_df.head(5)

# %%
mn_prec_df = mn_prec_df[["precinct", "votes"]]
# data["Team"]= data["Team"].str.split("t", n = 1, expand = True)

split_prec = mn_prec_df["precinct"].str.split("|", expand=True)

# %%
split_prec

# %%
mn_prec_df["new_prec"] = split_prec[0]
mn_prec_df["new_prec"] = mn_prec_df["new_prec"].str.title()

# %%
mn_prec_df.to_csv("test_precinct.csv")

# %%
i = 0
j = 0

for i <= countiesDF.length():
    for j <= prec_df.length():
        if countiesDF.iloc[i, 0] != prec_df.iloc[j,0]:
            print(countiesDF.iloc[i,0])
        j = j + 1
    i = i + 1
# Out:
#   File "<ipython-input-7-779d9c564791>", line 4
#     for i <= countiesDF.length():
#            ^
# SyntaxError: invalid syntax
